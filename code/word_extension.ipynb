# %% [markdown]
# # Add plurals

# %%
# load terms from file with pandas

import pandas as pd
import numpy as np
import nltk
import inflect

# load terms from file
path_to_terms = '../words/replacements.csv'
df_sg = pd.read_csv(path_to_terms, sep=',')
df_sg.head()
# Out:
#           word      variant  frequency category affix_type     replacement
# 0    spokesman    spokesman    18072.0      man     suffix    spokesperson
# 1   girlfriend   girlfriend     8436.0     girl     prefix         partner
# 2    boyfriend    boyfriend     6069.0      boy     prefix         partner
# 3  spokeswoman  spokeswoman     5731.0    woman     suffix    spokesperson
# 4  congressman  congressman     1702.0      man     suffix  congressperson

# %%
df_sg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335 entries, 0 to 334
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   word         335 non-null    object
#  1   variant      335 non-null    object
#  2   frequency    300 non-null    float64
#  3   category     335 non-null    object
#  4   affix_type   335 non-null    object
#  5   replacement  335 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 15.8+ KB

# %%
df_sg.affix_type.value_counts()
# Out:
# affix_type
# suffix    282
# prefix     53
# Name: count, dtype: int64

# %%
df_sg['number'] = 'SG'
df_sg.head()
# Out:
#           word      variant  frequency category affix_type     replacement  \
# 0    spokesman    spokesman    18072.0      man     suffix    spokesperson
# 1   girlfriend   girlfriend     8436.0     girl     prefix         partner
# 2    boyfriend    boyfriend     6069.0      boy     prefix         partner
# 3  spokeswoman  spokeswoman     5731.0    woman     suffix    spokesperson
# 4  congressman  congressman     1702.0      man     suffix  congressperson
#
#   number
# 0     SG
# 1     SG
# 2     SG
# 3     SG
# 4     SG

# %%
# get all words that end in -man
man_words = df_sg[(df_sg['category'] == 'man') & (df_sg['affix_type'] == 'suffix')]['word']
woman_words = df_sg[(df_sg['category'] == 'woman') & (df_sg['affix_type'] == 'suffix')]['word']

# %%
# replace -man with -woman
man_words_cut = [word[:-3]+'woman' for word in man_words]

# %%
# words that have a -woman ending but not a -man ending
for w in woman_words:
    if w not in man_words_cut:
        print(w)
# Out:
# charwoman
# man-woman
# anti-woman

# %%
excluded = ['manass']
for index, row in df_sg.iterrows():
    if row['word'] != row['variant'] and row['variant'] not in excluded:
        print(row['word'], row['variant'])
        new_row = {'word': row['variant'], 
               'variant': row['variant'], 
               'frequency': np.nan,
               'category': row['category'], 
               'affix_type': row['affix_type'], 
               'replacement': row['replacement'],
               'number': row['number'],
               'source': row['source']}
        df_sg.loc[len(df_sg)] = new_row
# Out:
# anti-woman antiwoman
# cabin-boy cabin boy
# con-boy conboy
# mad-man mad man
# man-cave man cave
# man-cession mancession
# man-friend manfriend
# man-hater man hater
# man-hating man hating
# man-hug man hug
# man-hunt man hunt
# man-kind mankind
# man-magnet man magnet
# man-marking man marking
# man-ny manny
# man-pack manpack
# man-power man power
# man-servant man servant
# man-stealing manstealing
# man-stopper manstopper
# man-up man up
# man-woman manwoman
# pot-boy potboy
# spy-master spy master

# %%
df_sg.tail()
# Out:
#               word        variant  frequency category affix_type  \
# 330  statesmanship  statesmanship        NaN  manship     suffix
# 331   stockmanship   stockmanship        NaN  manship     suffix
# 332  swordsmanship  swordsmanship        NaN  manship     suffix
# 333      upmanship      upmanship        NaN  manship     suffix
# 334    workmanship    workmanship        NaN  manship     suffix
#
#                  replacement number
# 330  public management skill     SG
# 331  livestock raising skill     SG
# 332            fencing skill     SG
# 333     competitive behavior     SG
# 334           workpersonship     SG

# %%
m = inflect.engine()
# input word to be pluralized 
example = 'man-bun'
# Pass the word to be pluralized as an argument to the plural() 
# function to make the word plural.
print(f"The plural form of {example} is: ", m.plural(example))
# Out:
# The plural form of man-bun is:  man-buns

# %%
# add plurals
plural_rows = []
jjs = ['boyish', 'girlish', 'man-made', 'manmade']

for index, row in df_sg.iterrows():
    replacement = row['replacement'].split(', ')
    word = row['word']
    pos = nltk.pos_tag([word])[0][1]
    if word in jjs:
        pass
    elif pos == 'NN':
        word_pl = m.plural(word)
        replacement_pl = ', '.join([m.plural(r) for r in replacement])
    elif pos == 'RB': # adverbs such as 'womanly'
        pass
    new_row = {'word': word_pl, 
               'variant': word_pl,
               'frequency': np.nan,
               'category': row['category'],
                'affix_type': row['affix_type'], 
               'replacement': replacement_pl, 
               'number': 'PL'}
    plural_rows.append(new_row)

df_plural = pd.DataFrame(plural_rows)

# %%
df_plural
# Out:
#                word         variant  frequency category affix_type  \
# 0         spokesmen       spokesmen        NaN      man     suffix
# 1       girlfriends     girlfriends        NaN     girl     prefix
# 2        boyfriends      boyfriends        NaN      boy     prefix
# 3       spokeswomen     spokeswomen        NaN    woman     suffix
# 4       congressmen     congressmen        NaN      man     suffix
# ..              ...             ...        ...      ...        ...
# 330  statesmanships  statesmanships        NaN  manship     suffix
# 331   stockmanships   stockmanships        NaN  manship     suffix
# 332  swordsmanships  swordsmanships        NaN  manship     suffix
# 333      upmanships      upmanships        NaN  manship     suffix
# 334    workmanships    workmanships        NaN  manship     suffix
#
#                   replacement number
# 0                spokespeople     PL
# 1                    partners     PL
# 2                    partners     PL
# 3                spokespeople     PL
# 4              congresspeople     PL
# ..                        ...    ...
# 330  public management skills     PL
# 331  livestock raising skills     PL
# 332            fencing skills     PL
# 333     competitive behaviors     PL
# 334           workpersonships     PL
#
# [335 rows x 7 columns]

# %%
# concatenate plural to original df
df = pd.concat([df_sg, df_plural])
df.sort_values(by=['category', 'word'], inplace=True)

# %%
df.head()
# Out:
#          word   variant  frequency category affix_type  replacement number
# 156   ballboy   ballboy        5.0      boy     suffix  ball person     SG
# 156  ballboys  ballboys        NaN      boy     suffix  ball people     PL
# 157    batboy    batboy        5.0      boy     suffix   bat person     SG
# 157   batboys   batboys        NaN      boy     suffix   bat people     PL
# 193   bellboy   bellboy        3.0      boy     suffix      bellhop     SG

# %%
print(len(df))
df.drop_duplicates(inplace=True, subset=['word', 'variant'])
print(len(df))
# Out:
# 670
# 659

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 659 entries, 156 to 227
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   word         659 non-null    object
#  1   variant      659 non-null    object
#  2   frequency    299 non-null    float64
#  3   category     659 non-null    object
#  4   affix_type   659 non-null    object
#  5   replacement  659 non-null    object
#  6   number       659 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 41.2+ KB

# %%
df.head(60)
# Out:
#            word     variant  frequency category affix_type  \
# 156     ballboy     ballboy        5.0      boy     suffix
# 156    ballboys    ballboys        NaN      boy     suffix
# 157      batboy      batboy        5.0      boy     suffix
# 157     batboys     batboys        NaN      boy     suffix
# 193     bellboy     bellboy        3.0      boy     suffix
# 193    bellboys    bellboys        NaN      boy     suffix
# 98      boyband     boyband       13.0      boy     prefix
# 98     boybands    boybands        NaN      boy     prefix
# 2     boyfriend   boyfriend     6069.0      boy     prefix
# 2    boyfriends  boyfriends        NaN      boy     prefix
# 60       boyish      boyish       32.0      boy     prefix
# 298    boyishly    boyishly        1.0      boy     prefix
# 174      boyism      boyism        4.0      boy     prefix
# 174     boyisms     boyisms        NaN      boy     prefix
# 118    boyscout    boyscout        9.0      boy     prefix
# 118   boyscouts   boyscouts        NaN      boy     prefix
# 299      boytoy      boytoy        1.0      boy     prefix
# 299     boytoys     boytoys        NaN      boy     prefix
# 55       busboy      busboy       37.0      boy     suffix
# 55      busboys     busboys        NaN      boy     suffix
# 277     callboy     callboy        1.0      boy     suffix
# 277    callboys    callboys        NaN      boy     suffix
# 276     copyboy     copyboy        1.0      boy     suffix
# 276    copyboys    copyboys        NaN      boy     suffix
# 7        cowboy      cowboy      523.0      boy     suffix
# 7       cowboys     cowboys        NaN      boy     suffix
# 144    doughboy    doughboy        6.0      boy     suffix
# 144   doughboys   doughboys        NaN      boy     suffix
# 18       fanboy      fanboy      159.0      boy     suffix
# 18      fanboys     fanboys        NaN      boy     suffix
# 172     farmboy     farmboy        4.0      boy     suffix
# 172    farmboys    farmboys        NaN      boy     suffix
# 274      femboy      femboy        1.0      boy     suffix
# 274     femboys     femboys        NaN      boy     suffix
# 271   fisherboy   fisherboy        1.0      boy     suffix
# 271  fisherboys  fisherboys        NaN      boy     suffix
# 217     fratboy     fratboy        2.0      boy     suffix
# 217    fratboys    fratboys        NaN      boy     suffix
# 60      freemen     freemen        NaN      boy     prefix
# 298  girlpowers  girlpowers        NaN      boy     prefix
# 273     headboy     headboy        1.0      boy     suffix
# 273    headboys    headboys        NaN      boy     suffix
# 67      homeboy     homeboy       26.0      boy     suffix
# 67     homeboys    homeboys        NaN      boy     suffix
# 158    houseboy    houseboy        5.0      boy     suffix
# 158   houseboys   houseboys        NaN      boy     suffix
# 171     ladyboy     ladyboy        4.0      boy     suffix
# 171    ladyboys    ladyboys        NaN      boy     suffix
# 272    nancyboy    nancyboy        1.0      boy     suffix
# 272   nancyboys   nancyboys        NaN      boy     suffix
# 192     newsboy     newsboy        3.0      boy     suffix
# 192    newsboys    newsboys        NaN      boy     suffix
# 63     paperboy    paperboy       28.0      boy     suffix
# 63    paperboys   paperboys        NaN      boy     suffix
# 17      playboy     playboy      163.0      boy     suffix
# 17     playboys    playboys        NaN      boy     suffix
# 61      plowboy     plowboy       31.0      boy     suffix
# 61     plowboys    plowboys        NaN      boy     suffix
# 45       tomboy      tomboy       55.0      boy     suffix
# 45      tomboys     tomboys        NaN      boy     suffix
#
#                    replacement number
# 156                ball person     SG
# 156                ball people     PL
# 157                 bat person     SG
# 157                 bat people     PL
# 193                    bellhop     SG
# 193                   bellhops     PL
# 98                        band     SG
# 98                       bands     PL
# 2                      partner     SG
# 2                     partners     PL
# 60                    childish     SG
# 298                 childishly     SG
# 174                   childism     SG
# 174                  childisms     PL
# 118                      scout     SG
# 118                     scouts     PL
# 299                        toy     SG
# 299                       toys     PL
# 55        restaurant attendant     SG
# 55       restaurant attendants     PL
# 277                 sex worker     SG
# 277                sex workers     PL
# 276    junior newspaper worker     SG
# 276   junior newspaper workers     PL
# 7                   cow herder     SG
# 7                  cow herders     PL
# 144               foot soldier     SG
# 144              foot soldiers     PL
# 18                         fan     SG
# 18                        fans     PL
# 172                farm worker     SG
# 172               farm workers     PL
# 274          effeminate person     SG
# 274          effeminate people     PL
# 271               young fisher     SG
# 271              young fishers     PL
# 217          fraternity member     SG
# 217         fraternity members     PL
# 60                  freepeople     PL
# 298                     powers     PL
# 273             student leader     SG
# 273            student leaders     PL
# 67               fellow member     SG
# 67              fellow members     PL
# 158            domestic worker     SG
# 158           domestic workers     PL
# 171         genderqueer person     SG
# 171         genderqueer people     PL
# 272                      nancy     SG
# 272                    nancies     PL
# 192  newspaper delivery person     SG
# 192  newspaper delivery people     PL
# 63   newspaper delivery person     SG
# 63   newspaper delivery people     PL
# 17                      player     SG
# 17                     players     PL
# 61                      plower     SG
# 61                     plowers     PL
# 45            boisterous child     SG
# 45         boisterous children     PL

# %%
save_path = '../words/replacements+plural.csv'
df.to_csv(save_path, index=False)

# %%
df_sg[df_sg['word'] == 'girlish'.lower()]['replacement'].values[0]
# Out:
# 'feminine'

# %%
final_path = '../words/replacements+plural-final.csv'

final_df = pd.read_csv(final_path)
print(final_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   word         692 non-null    object
#  1   replacement  692 non-null    object
#  2   category     692 non-null    object
#  3   affix_type   692 non-null    object
#  4   number       692 non-null    object
# dtypes: object(5)
# memory usage: 27.2+ KB
# None
